# %%
# !scrapy startproject car ../car
# Out:
# New Scrapy project 'car', using template directory 'C:\Users\dridi\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\templates\project', created in:
#     c:\Users\dridi\Desktop\BDYIA\Programacion de inteligencia artificial\TrabajoCoches\marcasCoches\car
#
# You can start your first spider with:
#     cd ../car
#     scrapy genspider example example.com

# %%
# !cd ../car/car && scrapy genspider "car_scrap" "https://informatica.ieszaidinvergeles.org:10099/pia/practica2/opel.html"
# Out:
# Created spider 'car_scrap' using template 'basic' in module:
#   car.spiders.car_scrap

# %%
# !cd ../car/car && scrapy crawl "car_scrap"

# %%
import json
import random
import time
from selenium.webdriver.common.by import By
import undetected_chromedriver.v2 as uc

# %%
driver = uc.Chrome()
list_link=[]
user_agents = ['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
                'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36',
                'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0',
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36',
                'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:24.0) Gecko/20100101 Firefox/24.0']
agents = len(user_agents) - 1

pages = ['https://www.coches.net/segunda-mano/?MakeId=69&MaxYear=2022&MinKms=10000&MinYear=2010', 
         'https://www.coches.net/segunda-mano/?MakeId=69&MaxYear=2022&MinKms=10000&MinYear=2010&pg=2',
         
         
         'https://www.coches.net/segunda-mano/?MakeId=18&MaxYear=2022&MinKms=10000&MinYear=2010',
         'https://www.coches.net/segunda-mano/?MakeId=18&MaxYear=2022&MinKms=10000&MinYear=2010&pg=2',
         'https://www.coches.net/segunda-mano/?MakeId=18&MaxYear=2022&MinKms=10000&MinYear=2010&pg=3',
         'https://www.coches.net/segunda-mano/?MakeId=18&MaxYear=2022&MinKms=10000&MinYear=2010&pg=4',
         'https://www.coches.net/segunda-mano/?MakeId=18&MaxYear=2022&MinKms=10000&MinYear=2010&pg=5',
         
         
         'https://www.coches.net/segunda-mano/?MakeId=20&MaxYear=2022&MinKms=10000&MinYear=2010',
         'https://www.coches.net/segunda-mano/?MakeId=20&MaxYear=2022&MinKms=10000&MinYear=2010&pg=2',
         'https://www.coches.net/segunda-mano/?MakeId=20&MaxYear=2022&MinKms=10000&MinYear=2010&pg=3',
         'https://www.coches.net/segunda-mano/?MakeId=20&MaxYear=2022&MinKms=10000&MinYear=2010&pg=4',
         'https://www.coches.net/segunda-mano/?MakeId=20&MaxYear=2022&MinKms=10000&MinYear=2010&pg=5',
         
         'https://www.coches.net/segunda-mano/?MakeId=21&MaxYear=2022&MinKms=10000&MinYear=2010',
         'https://www.coches.net/segunda-mano/?MakeId=21&MaxYear=2022&MinKms=10000&MinYear=2010&pg=2',
         'https://www.coches.net/segunda-mano/?MakeId=21&MaxYear=2022&MinKms=10000&MinYear=2010&pg=3',
         
         'https://www.coches.net/segunda-mano/?MakeId=22&MaxYear=2022&MinKms=10000&MinYear=2010',
         'https://www.coches.net/segunda-mano/?MakeId=22&MaxYear=2022&MinKms=10000&MinYear=2010&pg=2',
         'https://www.coches.net/segunda-mano/?MakeId=22&MaxYear=2022&MinKms=10000&MinYear=2010&pg=3',
         'https://www.coches.net/segunda-mano/?MakeId=22&MaxYear=2022&MinKms=10000&MinYear=2010&pg=4',
         'https://www.coches.net/segunda-mano/?MakeId=22&MaxYear=2022&MinKms=10000&MinYear=2010&pg=5'
         ]
first = True

for page in pages:
    increment = 100
    agent_number = random.randint(0, agents)
    driver.execute_cdp_cmd('Network.setUserAgentOverride', {"userAgent": user_agents[agent_number]})
    driver.get(page)
    if first:
        time.sleep(4)
        button = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div[2]/div/div/div/footer/div/button[2]")
        button.click()
        first = False
    while True:
        driver.execute_script("window.scrollTo(0, " + str(increment) + ");")
        time.sleep(0.2)
        elements = driver.find_elements(By.CLASS_NAME, 'mt-CardBasic-titleLink')
        increment += 200
        if len(elements) >= 30 or increment >= 6000:
            break
        time.sleep(random.randint(3, 5))
        
    for e in elements:
        link=e.get_attribute("href")
        print(link)
        list_link.append(link)
        
    

list_restult=[]
for l in list_link:
    if l not in list_restult:
        list_restult.append(l)
# Out:
# C:\Users\dridi\AppData\Local\Temp\ipykernel_1448\3992558737.py:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div[2]/div/div/div/footer/div/button[2]")
# https://www.coches.net/honda-crv-22-idtec-luxury-auto-5p-diesel-2015-en-madrid-51116692-covo.aspx
# https://www.coches.net/honda-hr-v-15-ivtec-cvt-executive-5p-gasolina-2015-en-barcelona-50373555-covo.aspx
# https://www.coches.net/honda-crv-15-vtec-turbo-4x4-cvt-elegance-navi-5p-gasolina-2019-en-madrid-51288119-covo.aspx
# https://www.coches.net/honda-crv-15-vtec-turbo-4x4-lifestyle-5p-gasolina-2019-en-cordoba-51148372-covo.aspx
# https://www.coches.net/honda-crv-16-idtec-118kw-4x4-lifestyle-nav-p-aut-5p-diesel-2017-en-pontevedra-51167626-covo.aspx
# https://www.coches.net/honda-accord-tourer-22-idtec-executive-diesel-2010-en-badajoz-51367578-covo.aspx
# ...

# %%
list_restult
# Out:
# ['https://www.coches.net/honda-crv-22-idtec-luxury-auto-5p-diesel-2015-en-madrid-51116692-covo.aspx',
#  'https://www.coches.net/honda-hr-v-15-ivtec-cvt-executive-5p-gasolina-2015-en-barcelona-50373555-covo.aspx',
#  'https://www.coches.net/honda-crv-15-vtec-turbo-4x4-cvt-elegance-navi-5p-gasolina-2019-en-madrid-51288119-covo.aspx',
#  'https://www.coches.net/honda-crv-15-vtec-turbo-4x4-lifestyle-5p-gasolina-2019-en-cordoba-51148372-covo.aspx',
#  'https://www.coches.net/honda-crv-16-idtec-118kw-4x4-lifestyle-nav-p-aut-5p-diesel-2017-en-pontevedra-51167626-covo.aspx',
#  'https://www.coches.net/honda-accord-tourer-22-idtec-executive-diesel-2010-en-badajoz-51367578-covo.aspx',
#  'https://www.coches.net/honda-crv-16-idtec-88kw-120cv-4x2-elegance-5p-diesel-2017-en-valencia-51323434-covo.aspx',
#  'https://www.coches.net/honda-civic-16-idtec-executive-5p-diesel-2015-en-zaragoza-51253511-covo.aspx',
# ...
